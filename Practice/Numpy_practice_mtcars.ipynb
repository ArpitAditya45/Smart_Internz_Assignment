# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# What is skewness?
# Skewness is a measure of the asymmetry of the probability distribution of a real-valued random variable about its mean.

# %%
df=pd.read_csv('/home/godslayer/Desktop/Smart_Internz_Assignment/Practice/Data_set/mtcars.csv')

# %%
df.hp.plot()
# Out:
# <Axes: >

# %%
sns.distplot(df.mpg)
# if you get bell shaped curve then you can replace it with mean else replace it with median
# Out:
# /tmp/ipykernel_8921/3399262203.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.mpg)
# <Axes: xlabel='mpg', ylabel='Density'>

# %%
data=[10,20,30,40,50]
#plotting pie chart
plt.pie(data,[0,0,0.1,0,0],labels=['a','b','c','d','e'],autopct='%1.1f%%',shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa444434590>,
# ...
#  [Text(1.075962358309037, 0.22870287165240302, 'a'),
#   Text(0.7360436312779136, 0.817459340184711, 'b'),
#   Text(-0.3708204787324998, 1.1412677917792124, 'c'),
#   Text(-1.0759623315431446, -0.2287029975759841, 'd'),
#   Text(0.5500001932481627, -0.9526278325909778, 'e')],
#  [Text(0.5868885590776565, 0.12474702090131072, '6.7%'),
#   Text(0.4014783443334074, 0.4458869128280241, '13.3%'),
#   Text(-0.21631194592729153, 0.6657395452045405, '20.0%'),
#   Text(-0.5868885444780788, -0.12474708958690041, '26.7%'),
#   Text(0.3000001054080887, -0.5196151814132606, '33.3%')])

# %%
x=np.arange(0,8)
y=np.arange(12,20)
plt.bar(x,y)
# Out:
# <BarContainer object of 8 artists>

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
fig,ax=plt.subplots(2,2)
ax[0,0].plot(x,y)
ax[0,1].plot(data)
ax[1,0].pie(data)
ax[1,1].bar(x,y)
# Out:
# <BarContainer object of 8 artists>

# %%
plt.boxplot(df.mpg)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fa443b54e50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fa443b54350>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fa443b54490>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fa443b56110>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa443b56810>],
#  'means': []}

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
d1=sns.load_dataset('tips')
display(d1)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(d1)
# Out:
# /home/godslayer/.local/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.jointplot(x='total_bill',y='tip',data=d1)

# %%
# ploting correlation matrix
d1.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(d1.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df=pd.DataFrame(np.random.rand(10,5),columns=['a','b','c','d','e'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       10 non-null     float64
#  1   b       10 non-null     float64
#  2   c       10 non-null     float64
#  3   d       10 non-null     float64
#  4   e       10 non-null     float64
# dtypes: float64(5)
# memory usage: 532.0 bytes
